# %%
# !git clone https://github.com/liturriago/AlphaDeforest.git
# %cd AlphaDeforest
# !pip install -e . -q
# %cd ..
# Out:
# Cloning into 'AlphaDeforest'...
# remote: Enumerating objects: 264, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 264 (delta 103), reused 222 (delta 67), pack-reused 0 (from 0)
# Receiving objects: 100% (264/264), 2.81 MiB | 19.60 MiB/s, done.
# Resolving deltas: 100% (103/103), done.
# /kaggle/working/AlphaDeforest
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.8 MB/s eta 0:00:00:00:010:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 76.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.3 MB/s eta 0:00:00
# ...

# %%
# !python /kaggle/working/AlphaDeforest/scripts/train.py --config /kaggle/working/AlphaDeforest/configs/traing_config.yaml --vis
# Out:
# Loading configuration from /kaggle/working/AlphaDeforest/configs/traing_config.yaml
#  Setting random seeds: 42
# Seeds fixed at: 42
# [TRAIN] Loading Training Dataset...
# Detected metadata files: 32
# Valid sequences built: 4
# [TEST] Loading FULL Dataset (Mode='full')...
# Detected metadata files: 32
# Valid sequences built: 4
# Initializing Model...
# Beginning training...
# Starting training on cuda for 100 epochs
# Training: 100%|█| 1/1 [00:01<00:00,  1.39s/it, Total=0.0168, Rec=0.0150, Pred=0.
# Epoch [1/100] | Loss: 0.0168
# Training: 100%|█| 1/1 [00:00<00:00,  3.18it/s, Total=0.0160, Rec=0.0147, Pred=0.
# Epoch [2/100] | Loss: 0.0160
# Training: 100%|█| 1/1 [00:00<00:00,  3.50it/s, Total=0.0155, Rec=0.0144, Pred=0.
# Epoch [3/100] | Loss: 0.0155
# Training: 100%|█| 1/1 [00:00<00:00,  3.72it/s, Total=0.0152, Rec=0.0142, Pred=0.
# Epoch [4/100] | Loss: 0.0152
# Training: 100%|█| 1/1 [00:00<00:00,  3.65it/s, Total=0.0149, Rec=0.0140, Pred=0.
# Epoch [5/100] | Loss: 0.0149
# ...
